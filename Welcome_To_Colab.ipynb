# %% [markdown]
# <a href="https://colab.research.google.com/github/John2617/work/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# # ASSIGNMENT 1

# %%
import pandas as pd
df=pd.read_csv('Missed1.csv')

# %%
df.head()
# Out:
#         Name  Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 0  Rob Stark        165.0         72.0            9.0               4.0
# 1      Sansa        150.0         48.0            6.0               NaN
# 2       Arya        155.0          NaN            8.0               3.0
# 3       Bran        162.0          NaN            7.0               NaN
# 4      Tywin        175.0         80.0           10.0               5.0
#
#    Academic Mark Average
# 0                   89.0
# 1                    NaN
# 2                   92.0
# 3                    NaN
# 4                    NaN

# %%
df.describe()
# Out:
#        Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# count    31.000000    20.000000      29.000000         24.000000
# mean    166.870968    66.300000       9.965517          4.375000
# std      21.715957    15.620836       3.886632          2.318405
# min      70.000000    20.000000       3.000000          2.000000
# 25%     160.000000    59.750000       7.000000          3.000000
# 50%     170.000000    66.500000      10.000000          4.000000
# 75%     178.500000    77.250000      12.000000          5.000000
# max     190.000000    90.000000      22.000000         10.000000
#
#        Academic Mark Average
# count              19.000000
# mean               79.578947
# std                16.381954
# min                44.000000
# 25%                71.000000
# 50%                82.000000
# 75%                92.000000
# max                98.000000

# %%
df.tail()
# Out:
#              Name  Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 29  little finger        190.0          NaN            NaN               6.0
# 30         aemond          NaN         78.0           22.0               8.0
# 31       rhaenyra          NaN         60.0            NaN               7.0
# 32         daemon        190.0          NaN           15.0              10.0
# 33         mathew         70.0          NaN            6.0               3.0
#
#     Academic Mark Average
# 29                   77.0
# 30                   44.0
# 31                    NaN
# 32                   97.0
# 33                    NaN

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Name                      0
# Height (cm)               3
# Weight (kg)              14
# Speed (km/hr)             5
# Confidence Level         10
# Academic Mark Average    15
# dtype: int64

# %%
df.isnull().values.transpose()
# Out:
# array([[False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False,  True,
#         False, False, False,  True,  True, False, False],
#        [False, False,  True,  True, False, False,  True, False,  True,
#         False, False,  True, False, False,  True,  True, False, False,
#         False,  True,  True,  True, False, False, False,  True, False,
#         False, False,  True, False, False,  True,  True],
#        [False, False, False, False, False, False, False, False, False,
#          True, False, False, False, False, False, False, False, False,
# ...

# %%
df.isnull().sum().sum()
# Out:
# 47

# %%
df['Height (cm)'].isnull().sum()
# Out:
# 3

# %%
df['Weight (kg)'].isnull().sum()
# Out:
# 14

# %%
df.isnull().sum().sort_values()
# Out:
# Name                      0
# Height (cm)               3
# Speed (km/hr)             5
# Confidence Level         10
# Weight (kg)              14
# Academic Mark Average    15
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Academic Mark Average    15
# Weight (kg)              14
# Confidence Level         10
# Speed (km/hr)             5
# Height (cm)               3
# Name                      0
# dtype: int64

# %%
df['Height (cm)'].sort_values(ascending=False)
# Out:
# 32    190.0
# 7     190.0
# 29    190.0
# 16    185.0
# 6     183.0
# 13    182.0
# 20    181.0
# 19    179.0
# 5     178.0
# 11    175.0
# 22    175.0
# 4     175.0
# 14    173.0
# 23    172.0
# 18    172.0
# 9     170.0
# 21    170.0
# 12    168.0
# 10    167.0
# 0     165.0
# 17    164.0
# 3     162.0
# 27    160.0
# 15    160.0
# 8     160.0
# 25    156.0
# 28    156.0
# 2     155.0
# 1     150.0
# 24    140.0
# 33     70.0
# 26      NaN
# 30      NaN
# 31      NaN
# Name: Height (cm), dtype: float64

# %%
df.fillna(900)
# Out:
#              Name  Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 0       Rob Stark        165.0         72.0            9.0               4.0
# 1           Sansa        150.0         48.0            6.0             900.0
# 2            Arya        155.0        900.0            8.0               3.0
# 3            Bran        162.0        900.0            7.0             900.0
# 4           Tywin        175.0         80.0           10.0               5.0
# 5           Jaime        178.0         77.0           12.0               4.0
# 6         Brienne        183.0        900.0           10.0             900.0
# 7         Tormund        190.0         90.0           14.0               3.0
# 8         Samwell        160.0        900.0            6.0               2.0
# 9           Theon        170.0         65.0          900.0               4.0
# 10           Yara        167.0         63.0           11.0             900.0
# ...

# %%
df['Weight (kg)'].fillna(800)
# Out:
# 0      72.0
# 1      48.0
# 2     800.0
# 3     800.0
# 4      80.0
# 5      77.0
# 6     800.0
# 7      90.0
# 8     800.0
# 9      65.0
# 10     63.0
# 11    800.0
# 12     59.0
# 13     85.0
# 14    800.0
# 15    800.0
# 16     80.0
# 17     57.0
# 18     68.0
# 19    800.0
# 20    800.0
# 21    800.0
# 22     65.0
# 23     65.0
# 24     20.0
# 25    800.0
# 26     49.0
# 27     70.0
# 28     75.0
# 29    800.0
# 30     78.0
# 31     60.0
# 32    800.0
# 33    800.0
# Name: Weight (kg), dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   34 non-null     object
#  1   Height (cm)            31 non-null     float64
#  2   Weight (kg)            20 non-null     float64
#  3   Speed (km/hr)          29 non-null     float64
#  4   Confidence Level       24 non-null     float64
#  5   Academic Mark Average  19 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.7+ KB

# %%
df1=df[['Height (cm)','Weight (kg)','Speed (km/hr)','Confidence Level','Academic Mark Average']]
df.fillna(df1.mean())
# Out:
#              Name  Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 0       Rob Stark   165.000000         72.0       9.000000             4.000
# 1           Sansa   150.000000         48.0       6.000000             4.375
# 2            Arya   155.000000         66.3       8.000000             3.000
# 3            Bran   162.000000         66.3       7.000000             4.375
# 4           Tywin   175.000000         80.0      10.000000             5.000
# 5           Jaime   178.000000         77.0      12.000000             4.000
# 6         Brienne   183.000000         66.3      10.000000             4.375
# 7         Tormund   190.000000         90.0      14.000000             3.000
# 8         Samwell   160.000000         66.3       6.000000             2.000
# 9           Theon   170.000000         65.0       9.965517             4.000
# 10           Yara   167.000000         63.0      11.000000             4.375
# ...

# %%
df1['Height (cm)'].fillna(df1['Height (cm)'].mean())
# Out:
# 0     165.000000
# 1     150.000000
# 2     155.000000
# 3     162.000000
# 4     175.000000
# 5     178.000000
# 6     183.000000
# 7     190.000000
# 8     160.000000
# 9     170.000000
# 10    167.000000
# 11    175.000000
# 12    168.000000
# 13    182.000000
# 14    173.000000
# 15    160.000000
# 16    185.000000
# 17    164.000000
# 18    172.000000
# 19    179.000000
# 20    181.000000
# 21    170.000000
# 22    175.000000
# 23    172.000000
# 24    140.000000
# 25    156.000000
# 26    166.870968
# 27    160.000000
# 28    156.000000
# 29    190.000000
# 30    166.870968
# 31    166.870968
# 32    190.000000
# 33     70.000000
# Name: Height (cm), dtype: float64

# %%
df1.fillna(df1.median())
# Out:
#     Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 0         165.0         72.0            9.0               4.0
# 1         150.0         48.0            6.0               4.0
# 2         155.0         66.5            8.0               3.0
# 3         162.0         66.5            7.0               4.0
# 4         175.0         80.0           10.0               5.0
# 5         178.0         77.0           12.0               4.0
# 6         183.0         66.5           10.0               4.0
# 7         190.0         90.0           14.0               3.0
# 8         160.0         66.5            6.0               2.0
# 9         170.0         65.0           10.0               4.0
# 10        167.0         63.0           11.0               4.0
# 11        175.0         66.5           15.0               5.0
# 12        168.0         59.0            9.0               4.0
# 13        182.0         85.0           12.0               4.0
# ...

# %%
df2=df1['Confidence Level'].fillna(df1['Confidence Level'].median())
print(df2)
# Out:
# 0      4.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      4.0
# 6      4.0
# 7      3.0
# 8      2.0
# 9      4.0
# 10     4.0
# 11     5.0
# 12     4.0
# 13     4.0
# 14     3.0
# 15     4.0
# 16     5.0
# 17     3.0
# 18     2.0
# 19     4.0
# 20     4.0
# 21     2.0
# 22     3.0
# 23     3.0
# 24     4.0
# 25     4.0
# 26     4.0
# 27     2.0
# 28    10.0
# 29     6.0
# 30     8.0
# 31     7.0
# 32    10.0
# 33     3.0
# Name: Confidence Level, dtype: float64

# %%
df1.fillna(df1.mode().iloc[0])
# Out:
#     Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 0         165.0         72.0            9.0               4.0
# 1         150.0         48.0            6.0               3.0
# 2         155.0         65.0            8.0               3.0
# 3         162.0         65.0            7.0               3.0
# 4         175.0         80.0           10.0               5.0
# 5         178.0         77.0           12.0               4.0
# 6         183.0         65.0           10.0               3.0
# 7         190.0         90.0           14.0               3.0
# 8         160.0         65.0            6.0               2.0
# 9         170.0         65.0            6.0               4.0
# 10        167.0         63.0           11.0               3.0
# 11        175.0         65.0           15.0               5.0
# 12        168.0         59.0            9.0               3.0
# 13        182.0         85.0           12.0               4.0
# ...

# %%
df2.fillna(df2.mode().iloc[0])
# Out:
# 0      4.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      4.0
# 6      4.0
# 7      3.0
# 8      2.0
# 9      4.0
# 10     4.0
# 11     5.0
# 12     4.0
# 13     4.0
# 14     3.0
# 15     4.0
# 16     5.0
# 17     3.0
# 18     2.0
# 19     4.0
# 20     4.0
# 21     2.0
# 22     3.0
# 23     3.0
# 24     4.0
# 25     4.0
# 26     4.0
# 27     2.0
# 28    10.0
# 29     6.0
# 30     8.0
# 31     7.0
# 32    10.0
# 33     3.0
# Name: Confidence Level, dtype: float64

# %%
df1['Height (cm)'].fillna(df1['Height (cm)'].mode().iloc[2])
# Out:
# 0     165.0
# 1     150.0
# 2     155.0
# 3     162.0
# 4     175.0
# 5     178.0
# 6     183.0
# 7     190.0
# 8     160.0
# 9     170.0
# 10    167.0
# 11    175.0
# 12    168.0
# 13    182.0
# 14    173.0
# 15    160.0
# 16    185.0
# 17    164.0
# 18    172.0
# 19    179.0
# 20    181.0
# 21    170.0
# 22    175.0
# 23    172.0
# 24    140.0
# 25    156.0
# 26    190.0
# 27    160.0
# 28    156.0
# 29    190.0
# 30    190.0
# 31    190.0
# 32    190.0
# 33     70.0
# Name: Height (cm), dtype: float64

# %%
df1.ffill()
# Out:
#     Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 0         165.0         72.0            9.0               4.0
# 1         150.0         48.0            6.0               4.0
# 2         155.0         48.0            8.0               3.0
# 3         162.0         48.0            7.0               3.0
# 4         175.0         80.0           10.0               5.0
# 5         178.0         77.0           12.0               4.0
# 6         183.0         77.0           10.0               4.0
# 7         190.0         90.0           14.0               3.0
# 8         160.0         90.0            6.0               2.0
# 9         170.0         65.0            6.0               4.0
# 10        167.0         63.0           11.0               4.0
# 11        175.0         63.0           15.0               5.0
# 12        168.0         59.0            9.0               5.0
# 13        182.0         85.0           12.0               4.0
# ...

# %%
df['Weight (kg)'].ffill()
# Out:
# 0     72.0
# 1     48.0
# 2     48.0
# 3     48.0
# 4     80.0
# 5     77.0
# 6     77.0
# 7     90.0
# 8     90.0
# 9     65.0
# 10    63.0
# 11    63.0
# 12    59.0
# 13    85.0
# 14    85.0
# 15    85.0
# 16    80.0
# 17    57.0
# 18    68.0
# 19    68.0
# 20    68.0
# 21    68.0
# 22    65.0
# 23    65.0
# 24    20.0
# 25    20.0
# 26    49.0
# 27    70.0
# 28    75.0
# 29    75.0
# 30    78.0
# 31    60.0
# 32    60.0
# 33    60.0
# Name: Weight (kg), dtype: float64

# %%
df1.bfill()
# Out:
#     Height (cm)  Weight (kg)  Speed (km/hr)  Confidence Level  \
# 0         165.0         72.0            9.0               4.0
# 1         150.0         48.0            6.0               3.0
# 2         155.0         80.0            8.0               3.0
# 3         162.0         80.0            7.0               5.0
# 4         175.0         80.0           10.0               5.0
# 5         178.0         77.0           12.0               4.0
# 6         183.0         90.0           10.0               3.0
# 7         190.0         90.0           14.0               3.0
# 8         160.0         65.0            6.0               2.0
# 9         170.0         65.0           11.0               4.0
# 10        167.0         63.0           11.0               5.0
# 11        175.0         59.0           15.0               5.0
# 12        168.0         59.0            9.0               4.0
# 13        182.0         85.0           12.0               4.0
# ...
